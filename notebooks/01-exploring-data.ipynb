# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from importlib.util import find_spec
if find_spec("core") is None:
    import sys
    sys.path.append('..')
    
from core.datasets import RetinaDataset
import tensorflow_datasets as tfds
tfds.disable_progress_bar()

# %%
ds = tfds.load('RetinaDataset', split='train', shuffle_files=True, as_supervised=True)

# %%
ds = ds.take(1)

for image, label in tfds.as_numpy(ds):
  print(image.shape, label)
# Out:
# (496, 512, 3) 3

# %%
ds, info = tfds.load('RetinaDataset', split='train', with_info=True)

fig = tfds.show_examples(ds, info)

# %%
info
# Out:
# tfds.core.DatasetInfo(
#     name='retina_dataset',
#     version=1.0.0,
#     description='Retinal OCT image dataset reflecting Drusen, DME, CNV and Normal',
#     homepage='https://www.kaggle.com/paultimothymooney/kermany2018',
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=4),
#     }),
#     total_num_examples=84457,
#     splits={
#         'test': 968,
#         'train': 83489,
#     },
#     supervised_keys=('image', 'label'),
#     citation="""title = {Retinal OCT image data}
#     author = {paultimothymooney}
#     publisher = {Kaggle}
#     url = {https://www.kaggle.com/paultimothymooney/kermany2018 }""",
#     redistribution_info=,
# )

# %%
# Example to download the data without tf record
#dl_manager = tfds.download.DownloadManager(download_dir = './scratch')
#extracted_path = dl_manager.download_and_extract('https://storage.googleapis.com/retinal_oct_archive/retinal_oct_test.zip')
